# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YRO2eIyaBQh3nIfGZ1lc")
project = rf.workspace("yoshiaki-upbfu").project("sweet_wrapper-2-njfu2")
version = project.version(11)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics -q

# %%
from ultralytics import YOLO

# Load a pretrained model (recommended for training on custom data)
model = YOLO('yolov8n.pt')

# Train the model
results = model.train(
    data='/home/atic/repo/litter_detect/datasets/ds12/data.yaml',
    epochs=100,
    imgsz=640
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.186 🚀 Python-3.10.12 torch-2.8.0+cu128 CUDA:0 (NVIDIA RTX A2000, 5791MiB)
# ...
