# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YRO2eIyaBQh3nIfGZ1lc")
project = rf.workspace("yoshiaki-upbfu").project("litters_segmentation-nzivj")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# Requirement already satisfied: roboflow in .\venv\lib\site-packages (1.2.6)
# Requirement already satisfied: certifi in .\venv\lib\site-packages (from roboflow) (2025.8.3)
# Requirement already satisfied: idna==3.7 in .\venv\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in .\venv\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\venv\lib\site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in .\venv\lib\site-packages (from roboflow) (3.10.5)
# Requirement already satisfied: numpy>=1.18.5 in .\venv\lib\site-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in .\venv\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in .\venv\lib\site-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in .\venv\lib\site-packages (from roboflow) (1.1.0)
# Requirement already satisfied: pillow-avif-plugin<2 in .\venv\lib\site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in .\venv\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in .\venv\lib\site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in .\venv\lib\site-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in .\venv\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in .\venv\lib\site-packages (from roboflow) (1.26.20)
# Requirement already satisfied: tqdm>=4.41.0 in .\venv\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in .\venv\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in .\venv\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in .\venv\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in .\venv\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in .\venv\lib\site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in .\venv\lib\site-packages (from matplotlib->roboflow) (4.59.0)
# Requirement already satisfied: packaging>=20.0 in .\venv\lib\site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in .\venv\lib\site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\venv\lib\site-packages (from requests->roboflow) (3.4.3)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in litters_segmentation-4 to yolov11:: 100%|██████████| 632339/632339 [00:36<00:00, 17256.72it/s]
# Extracting Dataset Version Zip to litters_segmentation-4 in yolov11:: 100%|██████████| 4784/4784 [00:06<00:00, 692.29it/s]

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# ここから元のコードが始まる
import torch
# from ultralytics import YOLO
# ...
from ultralytics import YOLO
model = YOLO("yolo11s.pt")
results = model.train(data="litters_segmentation-4\data.yaml", epochs=100, imgsz= 640, batch=4)
# Out:
# Ultralytics 8.3.204  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA RTX A2000, 6138MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=litters_segmentation-4\data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train45, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\dev\litter_segmentation\runs\detect\train45, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431452  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,620 parameters, 2,590,604 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 194.833.5 MB/s, size: 173.4 KB)
# train: Scanning C:\dev\litter_segmentation\litters_segmentation-4\train\labels.cache... 1944 images, 19 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1944/1944  0.0s
# val: Fast image access  (ping: 0.10.0 ms, read: 835.9120.6 MB/s, size: 347.8 KB)
# val: Scanning C:\dev\litter_segmentation\litters_segmentation-4\valid\labels.cache... 273 images, 50 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 273/273  0.0s
# Plotting labels to C:\dev\litter_segmentation\runs\detect\train45\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to C:\dev\litter_segmentation\runs\detect\train45
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100     0.648G      2.745      21.54     0.8674          8        640: 100% ━━━━━━━━━━━━ 486/486 3.4it/s 2:23<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 7.4it/s 4.8s0.1s
#                    all        273        265      0.493      0.158      0.194     0.0719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100     0.648G      3.015      14.31     0.8844          4        640: 70% ━━━━━━━━──── 340/486 6.9it/s 1:29<21.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 10
#       8 from ultralytics import YOLO
#       9 model = YOLO("yolo11n.pt")
# ---> 10 results = model.train(data="litters_segmentation-4\data.yaml", epochs=100, imgsz= 640, batch=4)
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\ultralytics\engine\model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\ultralytics\engine\trainer.py:235, in BaseTrainer.train(self)
#     232         ddp_cleanup(self, str(file))
#     234 else:
# --> 235     self._do_train()
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\ultralytics\engine\trainer.py:419, in BaseTrainer._do_train(self)
#     417     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     418 else:
# --> 419     loss, self.loss_items = self.model(batch)
#     420 self.loss = loss.sum()
#     421 if RANK != -1:
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\ultralytics\nn\tasks.py:138, in BaseModel.forward(self, x, *args, **kwargs)
#     124 """
#     125 Perform forward pass of the model for either training or inference.
#     126
#    (...)    135     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     136 """
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 138     return self.loss(x, *args, **kwargs)
#     139 return self.predict(x, *args, **kwargs)
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\ultralytics\nn\tasks.py:338, in BaseModel.loss(self, batch, preds)
#     335     self.criterion = self.init_criterion()
#     337 if preds is None:
# --> 338     preds = self.forward(batch["img"])
#     339 return self.criterion(preds, batch)
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\ultralytics\nn\tasks.py:139, in BaseModel.forward(self, x, *args, **kwargs)
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
#     138     return self.loss(x, *args, **kwargs)
# --> 139 return self.predict(x, *args, **kwargs)
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\ultralytics\nn\tasks.py:157, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     155 if augment:
#     156     return self._predict_augment(x)
# --> 157 return self._predict_once(x, profile, visualize, embed)
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\ultralytics\nn\tasks.py:180, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     178 if profile:
#     179     self._profile_one_layer(m, x, dt)
# --> 180 x = m(x)  # run
#     181 y.append(x if m.i in self.save else None)  # save output
#     182 if visualize:
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\ultralytics\nn\modules\block.py:317, in C2f.forward(self, x)
#     315 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     316     """Forward pass through C2f layer."""
# --> 317     y = list(self.cv1(x).chunk(2, 1))
#     318     y.extend(m(y[-1]) for m in self.m)
#     319     return self.cv2(torch.cat(y, 1))
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\ultralytics\nn\modules\conv.py:81, in Conv.forward(self, x)
#      71 def forward(self, x):
#      72     """
#      73     Apply convolution, batch normalization and activation to input tensor.
#      74
#    (...)     79         (torch.Tensor): Output tensor.
#      80     """
# ---> 81     return self.act(self.bn(self.conv(x)))
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\dev\litter_segmentation\venv\Lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
